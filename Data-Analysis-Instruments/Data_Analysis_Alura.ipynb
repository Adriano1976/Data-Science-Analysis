# %% [markdown]
# ![Blue Futuristic Technology Linkedln Banner.png](data:image/png;base64,...)

# %% [markdown]
# ### ***Verifique a versão da linguagem Python usando a função `python_version()`***

# %% [markdown]
# No código a seguir, está sendo usado o **módulo** `platform` para obter a versão da linguagem Python em execução. A **função** `python_version()` retorna a versão como uma string, que é então exibida pela **função** `print()`. O **objeto** resultante é a versão do Python, apresentada junto de uma mensagem informativa. Não há parâmetros adicionais passados à função `python_version()`.

# %%
from platform import python_version
print('Versão da Linguagem Python usada nesse Jupyter Notebook: ', python_version())
# Out:
# Versão da Linguagem Python usada nesse Jupyter Notebook:  3.11.3

# %% [markdown]
# # <font color=orange><strong>PASSO 1 - Análise de Dados com Pandas</strong></font>

# %% [markdown]
# ### ***Importando as bibliotecas necessárias***

# %% [markdown]
# No código a seguir, está sendo realizada a importação de módulos fundamentais para análise de dados em Python: **pandas** (módulo) com o apelido `pd` para manipulação de tabelas; **numpy** (módulo) com o apelido `np` para cálculos numéricos; **matplotlib.pyplot** (módulo) com o apelido `plt` para criação de gráficos; **seaborn** (módulo) com o apelido `sns` para visualizações estatísticas; e **plotly.express** (módulo) com o apelido `px` para gráficos interativos. Esses módulos fornecem funções, classes e métodos específicos que podem ser aplicados a **objetos** como DataFrames ou arrays. Os nomes após `as` são **parâmetros de apelido** usados para facilitar a chamada de funções e métodos desses módulos no restante do código.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### ***Carregando a base de dado a ser trabalhada usando a função `read_csv`***

# %% [markdown]
# No código a seguir, está sendo criada uma **string** (objeto `url`) que armazena o caminho de um arquivo CSV na web, enquanto o **método** `read_csv` da **classe** `pandas` (módulo `pd`) é utilizado para ler esse arquivo e carregá-lo em um **DataFrame** (objeto `df`). Os **parâmetros** usados são `delimiter=","` para indicar a separação por vírgula, `low_memory=False` para otimizar a leitura de grandes arquivos e `encoding='ISO-8859-1'` para definir a codificação de caracteres do arquivo.

# %%
url = "https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv"
df = pd.read_csv(url, delimiter=",", low_memory=False, encoding='ISO-8859-1')

# %% [markdown]
# ### ***Exibindo as linhas da base de dados com as funções `head()`, `tail()` e `sample()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **objeto** `df` (um DataFrame do módulo **pandas**) para visualizar diferentes partes dos dados: o **método** `head()` retorna as primeiras linhas, o **método** `tail()` retorna as últimas linhas e o **método** `sample(5)` retorna uma amostra aleatória de 5 registros. Esses métodos, chamados com diferentes **parâmetros** (no caso, o número de linhas), permitem explorar rapidamente o conteúdo e a distribuição dos dados carregados.

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.tail()
# Out:
#         work_year experience_level employment_type                 job_title  \
# 133344     2020.0               SE              FT            Data Scientist
# 133345     2021.0               MI              FT  Principal Data Scientist
# 133346     2020.0               EN              FT            Data Scientist
# 133347     2020.0               EN              CT     Business Data Analyst
# 133348     2021.0               SE              FT            Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 133344   412000             USD         412000                 US
# 133345   151000             USD         151000                 US
# 133346   105000             USD         105000                 US
# 133347   100000             USD         100000                 US
# 133348  7000000             INR          94665                 IN
#
#         remote_ratio company_location company_size
# 133344           100               US            L
# ...

# %%
df.sample(5)
# Out:
#        work_year experience_level employment_type          job_title  salary  \
# 97723     2024.0               MI              FT           Engineer  163000
# 73189     2024.0               SE              FT  Software Engineer  142700
# 62201     2024.0               EN              FT   Research Analyst   95520
# 17449     2025.0               SE              FT            Analyst   95000
# 7941      2025.0               SE              FT           Engineer  259700
#
#       salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 97723             USD         163000                 US           100
# 73189             USD         142700                 US             0
# 62201             USD          95520                 US             0
# 17449             USD          95000                 US             0
# 7941              USD         259700                 US             0
#
#       company_location company_size
# 97723               US            M
# ...

# %% [markdown]
# ### ***Verificando o número de linhas e colunas da base de dados***

# %% [markdown]
# No código a seguir, está sendo usada a **função** `print()` do Python para exibir dimensões do **objeto** `base`, que é um DataFrame do **módulo** `pandas`. O atributo `shape` retorna uma tupla com o número de linhas e colunas, onde o **parâmetro** `[0]` acessa a quantidade de linhas e `[1]` acessa a quantidade de colunas. Dessa forma, as mensagens exibem separadamente quantas linhas e colunas existem na base de dados.

# %%
print("Linhas: ", df.shape[0])
print("Colunas: ", df.shape[1])
# Out:
# Linhas:  133349
# Colunas:  11

# %% [markdown]
# ### ***Exibindo informações estruturais da tabela usando o método `info()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `info()` do **objeto** `df` (um DataFrame da **classe** `DataFrame` do módulo **pandas**) para exibir informações estruturais da tabela. Esse método mostra o número de entradas, o índice, os nomes e tipos das colunas, além da contagem de valores não nulos em cada coluna. O objetivo é fornecer uma visão geral da composição do conjunto de dados e auxiliar na identificação de possíveis valores ausentes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %% [markdown]
# ### ***Criando tabela estatísticas descritivas das colunas numéricas com o método `describe()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `describe()` do **objeto** `df` (um DataFrame da **classe** `DataFrame` do módulo **pandas**) para gerar estatísticas descritivas das colunas numéricas, como média, desvio padrão, valores mínimos, quartis e máximo. Em seguida, o **método** `round()` da **classe** `pandas.DataFrame` é aplicado como **função** externa para arredondar os valores dessas estatísticas para 2 casas decimais, facilitando a leitura e interpretação dos resultados.

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
round(df.describe(), 2)
# Out:
#        work_year       salary  salary_in_usd  remote_ratio
# count  133339.00    133349.00      133349.00     133349.00
# mean     2024.36    163283.32      157617.27         20.91
# std         0.68    217386.02       74288.36         40.59
# min      2020.00     14000.00       15000.00          0.00
# 25%      2024.00    106020.00      106000.00          0.00
# 50%      2024.00    147000.00      146206.00          0.00
# 75%      2025.00    199000.00      198000.00          0.00
# max      2025.00  30400000.00      800000.00        100.00

# %% [markdown]
# ### ***Visualizando os nomes das colunas do DataFrame usando o atributo `columns`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **atributo** `columns` do **objeto** `df` (um DataFrame da **classe** `DataFrame` do módulo **pandas**) para retornar um objeto do tipo **Index**, que contém os nomes das colunas do DataFrame. Esse atributo não é um método, portanto não requer parênteses, e serve para inspecionar a estrutura e os rótulos das variáveis presentes na base de dados.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ### ***Criando um dicionário para renomear as colunas do DataFrame***

# %% [markdown]
# No código a seguir, está sendo criado um **objeto** do tipo dicionário chamado `new_column_names` no Python. Cada par chave-valor desse dicionário representa uma correspondência entre nomes originais das colunas do **DataFrame** `base` (do **módulo** `pandas`) e novos nomes mais curtos ou padronizados. As **chaves** são strings com os nomes originais das colunas, e os **valores** são strings com os novos nomes que serão usados para renomeação, facilitando manipulação e análise dos dados posteriormente.

# %%
new_column_names = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

# %% [markdown]
# ### ***Renomeando os nomes das colunas do dicionário criado usando o método `rename()`***

# %% [markdown]
# No código a seguir, está sendo usado o **método** `rename()` da **classe** `DataFrame` do módulo **pandas**, aplicado ao **objeto** `df`, com o **parâmetro** `columns=new_column_names` para renomear os nomes das colunas conforme o dicionário `new_column_names`. O **parâmetro** `inplace=True` garante que a alteração seja feita diretamente no DataFrame original, sem necessidade de criar uma nova cópia. Em seguida, o **método** `head()` exibe as primeiras linhas do DataFrame atualizado.

# %%
df.rename(columns=new_column_names, inplace=True)
df.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %% [markdown]
# ### ***Analisando quais sãos as categorias das colunas categóricas***

# %% [markdown]
# No código a seguir, está sendo usado o **método** `value_counts()` da **classe** `Series` do módulo **pandas**, aplicado ao **objeto** `df['coluna_escolhido']`, que é uma coluna do DataFrame. Esse método conta a frequência de cada valor distinto presente na coluna, retornando uma nova **Series** com os valores únicos como índice e suas quantidades correspondentes como dados.

# %% [markdown]
# #### Nível de senioridade

# %%
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %% [markdown]
# | Sigla | Significado | Descrição                                 |
# |-------|-------------|--------------------------------------------|
# | SE    | Senior      | Profissional experiente (nível sênior)     |
# | MI    | Mid         | Nível intermediário                        |
# | EN    | Entry       | Iniciante ou júnior (entry-level)          |
# | EX    | Executive   | Executivo, liderança sênior (C-Level)      |

# %% [markdown]
# #### Tipo de contrato

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %% [markdown]
# | Sigla | Significado  | Descrição                                                           |
# |-------|--------------|----------------------------------------------------------------------|
# | FT    | Full-time    | Tempo integral – trabalho padrão de 40h/semana ou período completo   |
# | PT    | Part-time    | Meio período – carga horária reduzida                                |
# | CT    | Contract     | Contrato temporário ou por projeto – geralmente por prazo determinado|
# | FL    | Freelance    | Freelancer – trabalho autônomo ou por demanda, sem vínculo formal    |

# %% [markdown]
# #### Regime de trabalho

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %% [markdown]
# O modelo remoto permite trabalhar de qualquer lugar sem precisar ir à empresa. O modelo presencial exige ir até o escritório todos os dias. O híbrido mistura os dois modelos. O modelo 'everywhere' é mais raro e permite trabalhar de qualquer lugar do mundo sem restrição de país ou cidade.

# %% [markdown]
# | Sigla | Significado |
# |-------|-------------|
# | 0     | Presencial  |
# | 100   | Remoto      |
# | 50    | Híbrido     |

# %% [markdown]
# #### Tamanho da empresa

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %% [markdown]
# | Sigla | Significado  | Descrição                                                           |
# |-------|--------------|----------------------------------------------------------------------|
# | M   | Medium    | Empresa de tamanho médio|
# | L    | Large    | Empresa de tamanho grande                                |
# | S    | Small    | Empresa de tamanho pequeno|

# %% [markdown]
# ### ***Modificando o nome das categorias com os métodos `replace()` e `value_counts()`***

# %% [markdown]
# No código a seguir, está sendo criado um **dicionário** chamado `senioridade`, como exemplo, que mapeia abreviações para descrições completas. Em seguida, é usado o **método** `replace()` da **classe** `Series` do módulo **pandas** como **função** aplicada ao **objeto** `df['senioridade']`, como exemplo, substituindo os valores da coluna de acordo com o dicionário definido. Por fim, o método `value_counts()` é aplicado novamente ao mesmo **objeto**, retornando a contagem de ocorrências de cada nível de senioridade já traduzido.

# %%
senioridade = {
    'SE': 'senior',
    'MI': 'pleno',
    'EN': 'junior',
    'EX': 'executivo'
}
df['senioridade'] = df['senioridade'].replace(senioridade)
df['senioridade'].value_counts()
# Out:
# senioridade
# senior       77241
# pleno        40465
# junior       12443
# executivo     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT': 'integral',
    'PT': 'parcial',
    'CT': 'contrato',
    'FL': 'freelancer'
}
df['contrato'] = df['contrato'].replace(contrato)
df['contrato'].value_counts()
# Out:
# contrato
# integral      132563
# contrato         394
# parcial          376
# freelancer        16
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'L': 'grande',
    'S': 'pequena',
    'M':	'media'

}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# media      129561
# grande       3574
# pequena       214
# Name: count, dtype: int64

# %%
mapa_trabalho = {
    0: 'presencial',
    100: 'remoto',
    50: 'hibrido'
}

df['remoto'] = df['remoto'].replace(mapa_trabalho)
df['remoto'].value_counts()
# Out:
# remoto
# presencial    105312
# remoto         27718
# hibrido          319
# Name: count, dtype: int64

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `head()` da **classe** `DataFrame` do módulo **pandas**, aplicado ao **objeto** `df`. Esse método é uma **função** que retorna, por padrão, as 5 primeiras linhas do conjunto de dados, permitindo uma visualização inicial das colunas e de como os dados estão organizados. O parâmetro opcional `n` poderia ser passado para definir outra quantidade de linhas a serem exibidas.

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %% [markdown]
# ### ***Criando uma tabela estatísitca descritiva usando o método `describe()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `describe()` da **classe** `DataFrame` do módulo **pandas**, aplicado ao **objeto** `df`. Essa **função** gera estatísticas descritivas, e com o **parâmetro** `include='object'`, ela resume apenas as colunas de tipo categórico (objetos/strings), apresentando métricas como contagem de valores, número de categorias únicas, valor mais frequente (top) e frequência desse valor.

# %%
df.describe(include='object')
# Out:
#        senioridade  contrato           cargo   moeda residencia      remoto  \
# count       133349    133349          133349  133349     133349      133349
# unique           4         4             390      26        102           3
# top         senior  integral  Data Scientist     USD         US  presencial
# freq         77241    132563           17314  126140     119579      105312
#
#        empresa tamanho_empresa
# count   133349          133349
# unique      95               3
# top         US           media
# freq    119641          129561

# %% [markdown]
# **Com isso já conseguimos responder algumas perguntas, como:**
#
# * Qual o nível de experiência mais comum na base de dados?
# * Qual é o tipo de contrato mais frequente?
# * Qual o cargo mais frequente na amostra?
# * De qual país são a maioria dos profissionais da base?
# * Qual é o país onde mais empresas da amostra estão sediadas?
# * Qual o regime de trabalho mais comum?
# * Qual é o tamanho mais comum das empresas na amostra?

# %% [markdown]
# **O código é um passo a passo para entender, limpar e preparar a base de dados para análises mais profundas, facilitando a visualização de padrões e tendências no mercado de trabalho em ciência de dados.**

# %% [markdown]
# # <font color=orange><strong>PASSO 2 - Preparação e limpeza dos Dados</strong></font>

# %% [markdown]
# ### ***Identificando dados faltantes utilizando o método `isnull()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `isnull()` da **classe** `DataFrame` do módulo **pandas**, aplicado ao **objeto** `df`. Essa **função** retorna um novo **objeto DataFrame** com valores booleanos, em que cada célula indica `True` se o valor correspondente é nulo (ausente/NaN) ou `False` caso contrário, permitindo identificar onde existem dados faltantes.

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `head()` da **classe** `DataFrame` do módulo **pandas**, aplicado ao **objeto** `df`. Esse método é uma **função** que retorna, por padrão, as 5 primeiras linhas do conjunto de dados, permitindo uma visualização inicial das colunas e de como os dados estão organizados. O parâmetro opcional `n` poderia ser passado para definir outra quantidade de linhas a serem exibidas.

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %% [markdown]
# ### ***Verificando a soma de valores ausentes usando as funções `isnull()` e `sum()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `isnull()` da **classe** `DataFrame` do módulo **pandas**, combinado com o **método** `sum()`. O primeiro retorna um **objeto DataFrame** booleano que marca `True` para valores nulos, e o segundo soma os `True` (interpretados como 1) por coluna. Assim, o resultado é uma **série** com o total de valores ausentes em cada coluna do **objeto** `df`.

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %% [markdown]
# No código a seguir, está sendo usado o **método** `unique()` da **classe** `Series` do módulo **pandas**, aplicado ao **objeto** `df['ano']`. Esse método retorna um **array NumPy** contendo todos os valores únicos encontrados na coluna **ano**, sem repetição, permitindo identificar quais anos distintos estão presentes no conjunto de dados.

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %% [markdown]
# ### ***Buscando as linhas que possuem dados faltantes com os métodos `ismull()` e `any()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **objeto** `df` (um DataFrame da **classe** `DataFrame` do módulo **pandas**) em conjunto com os **métodos** `isnull()` e `any()`. O método `isnull()` retorna uma tabela booleana indicando valores ausentes, enquanto `any(axis=1)` identifica linhas com ao menos um valor nulo. Essa expressão é usada como **parâmetro** de filtragem no DataFrame, resultando em um novo subconjunto contendo apenas as linhas que possuem dados faltantes.

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade  contrato                      cargo  salario moeda  \
# 5588    NaN      senior  integral            Product Manager   184500   USD
# 59692   NaN       pleno  integral                   Engineer   110000   USD
# 59710   NaN      junior  integral             Data Scientist   208800   USD
# 59759   NaN      senior  integral          Software Engineer   135000   USD
# 59789   NaN      senior  integral                   Engineer   112000   USD
# 131000  NaN      senior  integral  Machine Learning Engineer   163800   USD
# 131006  NaN      senior  integral     Data Analytics Manager   204500   USD
# 133054  NaN      junior  integral             Data Scientist    40000   USD
# 133281  NaN       pleno  integral  Machine Learning Engineer   180000   PLN
# 133317  NaN       pleno  integral             Data Scientist   130000   USD
#
#            usd residencia      remoto empresa tamanho_empresa
# 5588    184500         US  presencial      US           media
# ...

# %% [markdown]
# ### ***Exemplos de como resolver problemas de valores ausentes em uma base de dados***

# %% [markdown]
# #### Preenchendo valores ausentes por valores **medianos** devidamente calculado

# %% [markdown]
# No código a seguir, está sendo criado o **objeto** `df_salarios`, um DataFrame da **classe** `DataFrame` do módulo **pandas**, contendo colunas de nomes e salários, incluindo valores nulos (`np.nan` do módulo **numpy**). Em seguida, são aplicados os **métodos** `fillna()` para substituir os valores ausentes, usando como **parâmetro** a média (`mean().round(2)`) e a mediana (`median()`) da coluna `salario`. Os resultados são armazenados em novas colunas, `salario_media` e `salario_mediana`, permitindo comparar as duas formas de imputação.

# %%
# Criação de um dataframe de teste para usar de exemplo
df_salarios = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
})

# calcula a média salarial e substitui os nulos pela média e arrededonda os valores
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

# calcula a mediana salarial e substitui os nulos pela mediana
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %% [markdown]
# #### Preenchendo valores ausentes com o **último** valor válido anterior

# %% [markdown]
# No código a seguir, está sendo criado o **objeto** `df_temperaturas`, um DataFrame da **classe** `DataFrame` do módulo **pandas**, que contém os dias da semana e suas respectivas temperaturas, incluindo valores nulos (`np.nan` do módulo **numpy**). Em seguida, é aplicado o **método** `ffill()` sobre a coluna `Temperatura`, que preenche valores ausentes com o último valor válido anterior. O resultado é armazenado em uma nova coluna chamada `preenchido_ffill`, permitindo observar como os nulos foram tratados por propagação direta.

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [30, np.nan, np.nan, 28, 27]
})

df_temperaturas["preenchido_ffill"] = df_temperaturas["Temperatura"].ffill()
df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_ffill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              30.0
# 2   Quarta          NaN              30.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %% [markdown]
# #### Preenchendo valores ausentes pelo **próximo** valor válido subsequente

# %% [markdown]
# No código a seguir, está sendo criado o **objeto** `df_temperaturas`, um DataFrame da **classe** `DataFrame` do módulo **pandas**, contendo dias da semana e valores de temperatura, onde alguns estão ausentes (`np.nan` do módulo **numpy**). Em seguida, é aplicado o **método** `bfill()` na coluna `Temperatura`, que substitui valores nulos pelo próximo valor válido subsequente. O resultado é armazenado no novo atributo `preenchido_bfill`, permitindo analisar como a técnica de preenchimento reverso trata os dados faltantes.

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"],
    "Temperatura": [30, np.nan, np.nan, 28, 27]
})

df_temperaturas["preenchido_bfill"] = df_temperaturas["Temperatura"].bfill()
df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_bfill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              28.0
# 2   Quarta          NaN              28.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %% [markdown]
# ### ***Criando uma nova coluna, mantendo as informações da linha original do DataFrame***

# %% [markdown]
# No código a seguir, está sendo criado o **objeto** `df_cidades`, um DataFrame da **classe** `DataFrame` do módulo **pandas**, contendo colunas de nomes e cidades, incluindo valores ausentes (`np.nan` do módulo **numpy**). Em seguida, é aplicado o **método** `fillna()` na coluna `cidade`, com o **parâmetro** `"Não informado"`, substituindo os valores nulos por essa string. O resultado é armazenado em uma nova coluna chamada `cidade_preenchida`, permitindo manter a informação de que a cidade não foi registrada sem perder a linha original do DataFrame.

# %%
df_cidades = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'cidade': ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]
})

df_cidades['cidade_preenchida'] = df_cidades["cidade"].fillna("Não informado")
display(df_cidades)
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `dropna()` da **classe** `DataFrame` do módulo **pandas**, aplicado ao **objeto** `df`. Esse método remove todas as linhas que possuem ao menos um valor nulo (`NaN`) e retorna um novo **DataFrame** chamado `df_limpo`, contendo apenas os registros completos, sem valores ausentes.

# %%
df_limpo = df.dropna()

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `isnull()` da **classe** `DataFrame` do módulo **pandas**, combinado com o **método** `sum()`. O primeiro retorna um **objeto DataFrame** booleano que marca `True` para valores nulos, e o segundo soma os `True` (interpretados como 1) por coluna. Assim, o resultado é uma **série** com o total de valores ausentes em cada coluna do **objeto** `df_limpo`.

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %% [markdown]
# ### ***Convertendo uma coluna numérica para o tipo Inteiro usando o método `assign()`***

# %% [markdown]
# No código a seguir, está sendo usado o **método** `assign()` da **classe** `DataFrame` do módulo **pandas**, aplicado ao **objeto** `df_limpo`, para criar ou atualizar a coluna `ano`. Dentro do `assign()`, o **método** `astype('int64')` é chamado sobre a **coluna** `df_limpo['ano']` para converter seus valores em inteiros de 64 bits. Em seguida, o **método** `dtypes` é utilizado como **atributo** do DataFrame para exibir os tipos de dados de todas as colunas no **objeto** `df_limpo`.

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))
df_limpo.dtypes
# Out:
# ano                 int64
# senioridade        object
# contrato           object
# cargo              object
# salario             int64
# moeda              object
# usd                 int64
# residencia         object
# remoto             object
# empresa            object
# tamanho_empresa    object
# dtype: object

# %% [markdown]
# # <font color=orange><strong>PASSO 3 - Visualização de Dados</strong></font>
# Aprendendo a criar gráficos estatísticos para explorar e comunicar informações presentes nos dados. Histogramas, boxplots, barras, etc.

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %% [markdown]
# ### ***Plotando um gráfico de barras usando o módulo `Matplotlib`***

# %% [markdown]
# No código a seguir, está sendo criado o **objeto** `df_seniority`, uma **Series** resultante do **método** `value_counts()` aplicado ao **objeto** `df_limpo['senioridade']`, contando a frequência de cada categoria. Em seguida, é criado o **objeto** `colors`, uma lista por **list comprehension** que define a cor vermelha para a barra com maior valor e azul para as demais. O **método** `plot(kind='bar', color=colors)` da **Series** gera um gráfico de barras personalizado, enquanto funções do módulo **matplotlib.pyplot** (`plt.title()`, `plt.xlabel()`, `plt.ylabel()`, `plt.tick_params()`, `plt.tight_layout()`, `plt.show()`) ajustam e exibem o gráfico.

# %%
df_seniority = df_limpo['senioridade'].value_counts()
colors = ['red' if count == df_seniority.max() else 'SteelBlue' for count in df_seniority]

df_seniority.plot(kind='bar', color=colors)
plt.title('Distribuição de Senioridade')
plt.xlabel('Senioridade')   
plt.ylabel('Quantidade de Pessoas')
plt.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ***Plotando gráfico de colunas usando a função `barplot()`***

# %% [markdown]
# No código a seguir, está sendo utilizado o **método** `barplot()` da **classe** `seaborn` (**sns**), aplicado ao **objeto** `df_limpo` com os **parâmetros** `x='senioridade'` e `y='usd'` para criar um gráfico de barras mostrando o salário médio por categoria de senioridade. Funções do módulo **matplotlib.pyplot** (`plt.title()`, `plt.xlabel()`, `plt.ylabel()`, `plt.tight_layout()`, `plt.show()`) são usadas para adicionar título, rótulos, ajustar o layout e exibir o gráfico.

# %%
sns.barplot(data=df_limpo, x='senioridade', y='usd')
plt.title('Salário médio por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário em USD')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='usd')
plt.title("Salário médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %% [markdown]
# No código a seguir, está sendo calculada a média salarial em dólar por nível de senioridade a partir do objeto `df_limpo`. O módulo **pandas** fornece o método `groupby`, que agrupa os dados pela coluna `senioridade`, e em seguida o método `mean`, que é a função estatística aplicada à coluna `usd`. O resultado é um objeto **Series** chamado `salary_mean`, onde o índice corresponde aos níveis de senioridade e os valores representam a média salarial. O método `sort_values` é chamado com o parâmetro `ascending=False`, organizando os salários em ordem decrescente. Por fim, a função `display` é usada para exibir o objeto resultante de forma legível.

# %%
salary_mean = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
display(salary_mean)
# Out:
# senioridade
# executivo    202027.667813
# senior       172850.838301
# pleno        143044.845979
# junior        99034.963267
# Name: usd, dtype: float64

# %% [markdown]
# No código a seguir, está sendo obtida a ordem dos níveis de senioridade com base na média salarial em dólar do **objeto** `df_limpo`. O módulo **pandas** fornece o método `groupby`, que agrupa os dados pela coluna `senioridade`, seguido do método `mean`, que calcula a média da coluna `usd`. Em seguida, o método `sort_values` com o **parâmetro** `ascending=True` organiza essas médias em ordem crescente, retornando um **objeto Index** que contém a sequência dos níveis de senioridade. Por fim, a função `display` exibe essa ordem de forma legível.

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index
display(ordem)
# Out:
# Index(['junior', 'pleno', 'senior', 'executivo'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', order=ordem)
plt.title("Salário médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %% [markdown]
# ### ***Criando um Histograma da Distribuição com a função `histplot()`***

# %% [markdown]
# Nos códigos a seguir, está sendo gerado dois histogramas da distribuição dos salários anuais usando os módulos **matplotlib.pyplot** (referenciado como `plt`) e **seaborn** (referenciado como `sns`). A função `plt.figure()` cria um objeto figura com parâmetros de tamanho definidos. O método `sns.histplot()` recebe como parâmetros o objeto `df_limpo['usd']` (coluna do DataFrame), , `bins=7` define o número de intervalos no primeiro gráfico e `bins=18` definindo o número de intervalos devidamente calculado. Tém também a opção `kde=True` para exibir a curva de densidade. Em seguida, os métodos `plt.title()`, `plt.xlabel()` e `plt.ylabel()` configuram título e eixos. Por fim, a função `plt.show()` exibe o gráfico.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df_limpo['usd'], bins = 50, kde=True)
plt.title("Distribuição dos salários anuais")
plt.xlabel("Salário em USD")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# ### ***Calculando o número de bins para um histograma usando a função `log10`***

# %% [markdown]
# No código a seguir, está sendo usado o **módulo** `numpy` como `np` para calcular o número ideal de **bins** para um histograma com base na **Regra de Sturges**. O **objeto** `base_dropna` é um DataFrame do **módulo** `pandas`, e `base_dropna.shape[0]` retorna o número de linhas (observações). A **função** `np.log10()` calcula o logaritmo decimal do total de observações. O resultado é armazenado no **objeto** `k_sturges` e exibido com a **função** `print()`, formatado para duas casas decimais usando f-string.

# %%
k_sturges = 1 + 3.322 * np.log10(df_limpo.shape[0])
print(f"Número de bins pela Regra de Sturges: {k_sturges:.2f}")
# Out:
# Número de bins pela Regra de Sturges: 18.03

# %%
plt.figure(figsize=(10,5))
sns.histplot(df_limpo['usd'], bins = 18, kde=True)
plt.title("Distribuição dos salários anuais")
plt.xlabel("Salário em USD")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# ### ***Criando gráfico de caixa que mostra a distribuição da variável com a função `boxplot()`***

# %% [markdown]
# No código a seguir, está sendo criado um boxplot para analisar a distribuição dos salários anuais em dólares. O módulo **matplotlib.pyplot** (referenciado como `plt`) é utilizado para definir a figura e exibir o gráfico, enquanto o módulo **seaborn** (referenciado como `sns`) fornece a função `boxplot()`. Essa função recebe como parâmetro o objeto `df_limpo['usd']`, que representa a série de salários. Os métodos `plt.title()` e `plt.xlabel()` configuram o título e o rótulo do eixo. Por fim, a função `plt.show()` renderiza o gráfico gerado.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_limpo['usd'])
plt.title("Boxplot Salário")
plt.xlabel("Salário em USD")
plt.show()

# %% [markdown]
# No código a seguir, está sendo construído um **boxplot** que compara a distribuição dos salários em dólares de acordo com os níveis de **senioridade**. O módulo **matplotlib.pyplot** (apelidado de `plt`) é responsável por configurar e exibir o gráfico, enquanto o módulo **seaborn** (apelidado de `sns`) fornece a função `boxplot()`. Essa função recebe como parâmetros o nome da coluna de categorização (`'senioridade'`), a coluna numérica (`'usd'`), o objeto **DataFrame** `df_limpo` e a lista `ordem_senioridade` que define a ordem personalizada das categorias. Por fim, os métodos `plt.title()`, `plt.xlabel()` e `plt.show()` ajustam rótulos e exibem o gráfico.

# %%
ordem_senioridade = ['junior', 'pleno', 'senior', 'executivo']

plt.figure(figsize=(10,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade)
plt.title("Boxplot da distribuição por senioridade")
plt.xlabel("Salário em USD")
plt.show()

# %%
ordem_senioridade = ['junior', 'pleno', 'senior', 'executivo']

plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade, palette='Set2')
plt.title("Boxplot da distribuição por senioridade")

plt.xlabel("Salário em USD")
plt.show()

# %% [markdown]
# ### ***Crie um gráfico de média salarial por senioridade em barras usando a função `bar`***

# %% [markdown]
# No código a seguir, está sendo construída uma visualização interativa de barras para comparar a média salarial anual em dólar por nível de senioridade. O módulo **pandas** fornece o método `groupby`, que agrupa o objeto `df_limpo` pela coluna `senioridade` e aplica a função `mean` ao campo `usd`, gerando o objeto `senioridade_media_salario`. Em seguida, é criada a lista `cores`, que usa uma compreensão de lista para definir a cor vermelha apenas para o maior valor e a cor **SteelBlue** para os demais. O módulo **plotly.express** fornece a função `px.bar`, que recebe parâmetros como `x`, `y`, `title` e `labels`, além de `color_discrete_sequence`, que recebe o objeto `cores` para controlar as cores. Por fim, o método `update_layout` ajusta parâmetros do gráfico como `width`, `height` e `showlegend`, e o método `fig.show` exibe a visualização.

# %%
media_salario = df_limpo.groupby('senioridade', as_index=False)['usd'].mean()
cores = ['red' if count == media_salario['usd'].max() else 'SteelBlue' for count in media_salario['usd']] 

fig = px.bar(
    media_salario,
    x='senioridade',
    y='usd',
    title='Média Salarial por Senioridade',
    labels={'senioridade': 'Nível de Senioridade', 'usd': 'Média Salarial Anual (USD)'},
    color='senioridade',
    color_discrete_sequence=cores
)

fig.update_layout(
    width=700,
    height=500,
    showlegend=False
)

fig.show()

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem
# Out:
#        remoto   count
# 0  presencial  105305
# 1      remoto   27716
# 2     hibrido     318

# %%
media_remoto = df_limpo.groupby('remoto', as_index=False)['usd'].mean()
cores = ['red' if count == media_remoto['usd'].max() else 'SteelBlue' for count in media_remoto['usd']] 

fig = px.bar(
    media_remoto,
    x='remoto',
    y='usd',
    title='Média Salarial por Tipo de Trabalho',
    labels={'remoto': 'Tipo de Trabalho', 'usd': 'Média Salarial Anual (USD)'},
    color='remoto',
    color_discrete_sequence=cores
)

fig.update_layout(
    width=700,
    height=500,
    showlegend=False
)

fig.show()

# %%
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
colors = ['red' if count == df_seniority.max() else 'SteelBlue' for count in remoto_contagem]

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             color_discrete_sequence=px.colors.sequential.RdBu)

fig.update_layout(
    width=700,
    height=500,
    showlegend=True
)

fig.show()

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['remoto', 'contagem']
colors = ['red' if count == df_seniority.max() else 'SteelBlue' for count in remoto_contagem]

display(remoto_contagem)
# Out:
#        remoto  contagem
# 0  presencial    105305
# 1      remoto     27716
# 2     hibrido       318

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
colors = ['red' if count == df_seniority.max() else 'SteelBlue' for count in remoto_contagem]

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             color_discrete_sequence=px.colors.sequential.RdBu,
             hole=0.5
          )

fig.update_layout(
    width=700,
    height=500,
    showlegend=True
)

fig.show()

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
colors = ['red' if count == df_seniority.max() else 'SteelBlue' for count in remoto_contagem]

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             color_discrete_sequence=px.colors.sequential.RdBu,
             hole=0.5
          )
fig.update_traces(textinfo='percent+label')

fig.update_layout(
    width=700,
    height=500,
    showlegend=True
)

fig.show()

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
# %pip install pycountry
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %% [markdown]
# ### ***Criando mapa interativo usando a função `countries` do módulo `pycountry`***

# %% [markdown]
# No código a seguir, está sendo criado um **mapa interativo** para visualizar a média salarial de Cientistas de Dados por país. O módulo **pycountry** é usado para conversão de códigos ISO-2 para ISO-3, implementada na **função** `iso2_to_iso3(code)`, que retorna `alpha_3` ou `None` em caso de erro. O método `apply` da **classe** `DataFrame` aplica essa função à **coluna** `df_limpo['residencia']`, criando o **objeto** `residencia_iso3`. Em seguida, o **objeto** `df_ds` filtra linhas com `cargo == 'Data Scientist'`, e o método `groupby` calcula a média salarial (`mean`) por país, retornando `media_ds_pais`. O módulo **plotly.express** fornece a função `px.choropleth`, que recebe parâmetros como `locations`, `color`, `color_continuous_scale`, `title` e `labels` para gerar o mapa, e o método `fig.show` exibe a visualização interativa.

# %%
import pycountry # type: ignore

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa residencia_iso3
# 0         US      remoto      US           media             USA
# 1         US      remoto      US           media             USA
# 2         AU  presencial      AU           media             AUS
# 3         AU  presencial      AU           media             AUS
# 4         US  presencial      US           media             USA

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)

# %% [markdown]
# # Aula 4 - Construindo um Dashboard com Streamlit
#
# > Aprender a usar a biblioteca Streamlit para a criação de um dashboard interativo simples, que permite visualizar dados filtrados e gerar gráficos de forma prática.

# %% [markdown]
# https://dashboard-salarios-dados.streamlit.app/

# %% [markdown]
# 1. Criar o ambiente virtual:
#
# ```bash
# python3 -m venv .venv
# ```
#
# 2. Ativar o ambiente virtual em Windows:
#
# ```bash
# .venv\Scripts\Activate
# ```
#
# 3. Ativar o ambiente virtual em MAC/LINUX:
# ```bash
# source .venv/bin/activate
# ```
#
# 4. Criar um arquivo chamado requirements.txt e adicionar os pacotes necessários
#
# ```bash
# pandas==2.2.3
# streamlit==1.44.1
# plotly==5.24.1
# ```
#
# 5. Instalar as bibliotecas necessárias
#
# ```bash
# pip install -r requirements.txt
# ```
#
# 6. Criar a Interface do Dashboard com Streamlit
#
# 7. Realizar o deploy do Dashboard no Streamlit Cloud: https://streamlit.io/cloud

# %% [markdown]
# .

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# --- Configuração da Página ---
# Define o título da página, o ícone e o layout para ocupar a largura inteira.
st.set_page_config(
    page_title="Dashboard de Salários na Área de Dados",
    page_icon="📊",
    layout="wide",
)

# --- Carregamento dos dados ---
df = pd.read_csv("https://raw.githubusercontent.com/vqrca/dashboard_salarios_dados/refs/heads/main/dados-imersao-final.csv")

# --- Barra Lateral (Filtros) ---
st.sidebar.header("🔍 Filtros")

# Filtro de Ano
anos_disponiveis = sorted(df['ano'].unique())
anos_selecionados = st.sidebar.multiselect("Ano", anos_disponiveis, default=anos_disponiveis)

# Filtro de Senioridade
senioridades_disponiveis = sorted(df['senioridade'].unique())
senioridades_selecionadas = st.sidebar.multiselect("Senioridade", senioridades_disponiveis, default=senioridades_disponiveis)

# Filtro por Tipo de Contrato
contratos_disponiveis = sorted(df['contrato'].unique())
contratos_selecionados = st.sidebar.multiselect("Tipo de Contrato", contratos_disponiveis, default=contratos_disponiveis)

# Filtro por Tamanho da Empresa
tamanhos_disponiveis = sorted(df['tamanho_empresa'].unique())
tamanhos_selecionados = st.sidebar.multiselect("Tamanho da Empresa", tamanhos_disponiveis, default=tamanhos_disponiveis)

# --- Filtragem do DataFrame ---
# O dataframe principal é filtrado com base nas seleções feitas na barra lateral.
df_filtrado = df[
    (df['ano'].isin(anos_selecionados)) &
    (df['senioridade'].isin(senioridades_selecionadas)) &
    (df['contrato'].isin(contratos_selecionados)) &
    (df['tamanho_empresa'].isin(tamanhos_selecionados))
]

# --- Conteúdo Principal ---
st.title("🎲 Dashboard de Análise de Salários na Área de Dados")
st.markdown("Explore os dados salariais na área de dados nos últimos anos. Utilize os filtros à esquerda para refinar sua análise.")

# --- Métricas Principais (KPIs) ---
st.subheader("Métricas gerais (Salário anual em USD)")

if not df_filtrado.empty:
    salario_medio = df_filtrado['usd'].mean()
    salario_maximo = df_filtrado['usd'].max()
    total_registros = df_filtrado.shape[0]
    cargo_mais_frequente = df_filtrado["cargo"].mode()[0]
else:
    salario_medio, salario_mediano, salario_maximo, total_registros, cargo_mais_comum = 0, 0, 0, ""

col1, col2, col3, col4 = st.columns(4)
col1.metric("Salário médio", f"${salario_medio:,.0f}")
col2.metric("Salário máximo", f"${salario_maximo:,.0f}")
col3.metric("Total de registros", f"{total_registros:,}")
col4.metric("Cargo mais frequente", cargo_mais_frequente)

st.markdown("---")

# --- Análises Visuais com Plotly ---
st.subheader("Gráficos")

col_graf1, col_graf2 = st.columns(2)

with col_graf1:
    if not df_filtrado.empty:
        top_cargos = df_filtrado.groupby('cargo')['usd'].mean().nlargest(10).sort_values(ascending=True).reset_index()
        grafico_cargos = px.bar(
            top_cargos,
            x='usd',
            y='cargo',
            orientation='h',
            title="Top 10 cargos por salário médio",
            labels={'usd': 'Média salarial anual (USD)', 'cargo': ''}
        )
        grafico_cargos.update_layout(title_x=0.1, yaxis={'categoryorder':'total ascending'})
        st.plotly_chart(grafico_cargos, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de cargos.")

with col_graf2:
    if not df_filtrado.empty:
        grafico_hist = px.histogram(
            df_filtrado,
            x='usd',
            nbins=30,
            title="Distribuição de salários anuais",
            labels={'usd': 'Faixa salarial (USD)', 'count': ''}
        )
        grafico_hist.update_layout(title_x=0.1)
        st.plotly_chart(grafico_hist, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de distribuição.")

col_graf3, col_graf4 = st.columns(2)

with col_graf3:
    if not df_filtrado.empty:
        remoto_contagem = df_filtrado['remoto'].value_counts().reset_index()
        remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
        grafico_remoto = px.pie(
            remoto_contagem,
            names='tipo_trabalho',
            values='quantidade',
            title='Proporção dos tipos de trabalho',
            hole=0.5
        )
        grafico_remoto.update_traces(textinfo='percent+label')
        grafico_remoto.update_layout(title_x=0.1)
        st.plotly_chart(grafico_remoto, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico dos tipos de trabalho.")

with col_graf4:
    if not df_filtrado.empty:
        df_ds = df_filtrado[df_filtrado['cargo'] == 'Data Scientist']
        media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
        grafico_paises = px.choropleth(media_ds_pais,
            locations='residencia_iso3',
            color='usd',
            color_continuous_scale='rdylgn',
            title='Salário médio de Cientista de Dados por país',
            labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
        grafico_paises.update_layout(title_x=0.1)
        st.plotly_chart(grafico_paises, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de países.")

# --- Tabela de Dados Detalhados ---
st.subheader("Dados Detalhados")
st.dataframe(df_filtrado)
# Out:
# DeltaGenerator()
